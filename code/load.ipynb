# %%
import pandas as pd

# %%
df = pd.read_json('../data/apollo 16.json')

# %%
df.head()
# Out:
#    GENERIC  SAMPLEID    MISSION STATION LANDMARK  BAGNUMBER  ORIGINALWEIGHT  \
# 0    60001     416.0  Apollo 16      LM     None        NaN            30.1
# 1    60002     417.0  Apollo 16      LM     None        NaN           211.8
# 2    60003     418.0  Apollo 16      LM     None        NaN           215.9
# 3    60004     419.0  Apollo 16      LM     None        NaN           202.7
# 4    60005     420.0  Apollo 16      LM     None        NaN            77.3
#
#   SAMPLETYPE SAMPLESUBTYPE  PRISTINITY              PRISTINITYDATE  \
# 0       Core      unsieved      45.488  November, 13 2013 00:00:00
# 1       Core      unsieved      74.021  November, 13 2013 00:00:00
# 2       Core      unsieved      74.876  November, 13 2013 00:00:00
# 3       Core      unsieved      72.856  November, 13 2013 00:00:00
# 4       Core      unsieved      95.962     March, 30 2012 00:00:00
#
#    HASTHINSECTION  HASDISPLAYSAMPLE DISPLAYSAMPLENUMBER GENERICDESCRIPTION
# ...
